# %%
import os
os.chdir('/root/DWDP')
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /root/DWDP

# %%
import gdown
import zipfile

def download_data():
    file_id = '1iTM57U43L0ANn1u_bRv4dEEERQemuOXc'
    destination = 'Denoising_Dataset_train_val.zip'

    # Download the file from Google Drive
    gdown.download(f'https://drive.google.com/uc?id={file_id}', destination, quiet=False)

    # Unzip the downloaded file into the 'data' folder
    with zipfile.ZipFile(destination, 'r') as zip_ref:
        zip_ref.extractall('data')  # Extract dataset into 'data' folder

# %%
download_data()
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1iTM57U43L0ANn1u_bRv4dEEERQemuOXc
# From (redirected): https://drive.google.com/uc?id=1iTM57U43L0ANn1u_bRv4dEEERQemuOXc&confirm=t&uuid=536167fd-d11d-4b4d-a9db-bd7eeaab36e4
# To: /root/DWDP/Denoising_Dataset_train_val.zip
# 100%|██████████| 3.78G/3.78G [19:25<00:00, 3.25MB/s]

# %%
zip_file_path = 'Denoising_Dataset_train_val.zip'
extract_to_path = './'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_path)

print("File extracted to the directory.")
# Out:
# File extracted to the directory.

# %%
import os
import shutil

def rearrange_and_rename_files(src_dir, dest_dir):
    """
    Rearranges the folder structure from:
    - src_dir/Class/Train/[Defect_mask/defect_type/images, Degraded_image/defect_type/images, clean_image/defect_type/images]
    
    To:
    - dest_dir/Train_or_Val/class_name_defect_type/Defect/images, Degraded/images, Ground_Truth/images
    
    Args:
        src_dir (str): The source directory of the original structure.
        dest_dir (str): The destination directory for the new structure.
    """
    # Loop through each class in the source directory
    for class_name in os.listdir(src_dir):
        class_path = os.path.join(src_dir, class_name)
        if os.path.isdir(class_path):
            # Process both Train and Val folders
            for split in ['Train', 'Val']:
                split_path = os.path.join(class_path, split)
                if os.path.exists(split_path):
                    print(f"Processing {split} folder for class: {class_name}")

                    # Loop through categories: Defect_mask, Degraded_image, and clean_image
                    for category, folder_name in zip(
                        ['Defect_mask', 'Degraded_image', 'GT_clean_image'],
                        ['defect_mask','degraded', 'ground_truth']
                    ):
                        category_path = os.path.join(split_path, category)
                        if os.path.exists(category_path):
                            # Loop through defect types (subclass)
                            for defect_type in os.listdir(category_path):
                                defect_type_path = os.path.join(category_path, defect_type)

                                if os.path.isdir(defect_type_path):
                                    print(f"  Processing defect type: {defect_type} in category: {category}")

                                    # Define the destination directory
                                    dest_category_path = os.path.join(dest_dir, split, folder_name)
                                    os.makedirs(dest_category_path, exist_ok=True)

                                    # Copy images with renamed filenames
                                    for i, filename in enumerate(sorted(os.listdir(defect_type_path)), start=1):
                                        src_image_path = os.path.join(defect_type_path, filename)
                                        new_filename = f"{class_name}_{defect_type}_{i:03d}.png"
                                        dest_image_path = os.path.join(dest_category_path, new_filename)
                                        
                                        if os.path.isfile(src_image_path):
                                            shutil.copy2(src_image_path, dest_image_path)
                                            print(f"Copied {src_image_path} to {dest_image_path}")
                                        else:
                                            print(f"Skipped non-file item: {src_image_path}")
                        else:
                            print(f"Category {category} does not exist in {split} for class {class_name}")

# Example usage
src_dir = 'Denoising_Dataset_train_val'
dest_dir = 'structured_data'
rearrange_and_rename_files(src_dir, dest_dir)
# Out:
# Processing Train folder for class: cable
#   Processing defect type: missing_wire in category: Defect_mask
# Copied Denoising_Dataset_train_val/cable/Train/Defect_mask/missing_wire
category: Defect_mask
# Copied Denoising_Dataset_train_val/cable/Val/Defect_mask/missing_cable/006_mask.png to structured_data/Val/defect_mask/cable_missing_cable_001.png
#   Processing defect type: poke_insulation in category: Defect_mask
# Copied Denoising_Dataset_train_val/cable/Val/Defect_mask/poke_insulation/008_mask.png to structured_data/Val/defect_mask/cable_poke_insulation_001.png
#   Processing defect type: cut_inner_insulation in category: Defect_mask
# Copied Denoising_Dataset_train_val/cable/Val/Defect_mask/cut_inner_insulation/007_mask.png to structured_data/Val/defect_mask/cable_cut_inner_insulation_001.png
#   Processing defect type: cable_swap in category: Defect_mask
# Copied Denoising_Dataset_train_val/cable/Val/Defect_mask/cable_swap/007_mask.png to structured_data/Val/defect_mask/cable_cable_swap_001.png
#   Processing defect type: missing_wire in category: Degraded_image
# Copied Denoising_Dataset_train_val/cable/Val/Degraded_image/missing_wire/007.png to structured_data/Val/degraded/cable_missing_wire_001.png
#   Processing defect type: combined in category: Degraded_image
# Copied Denoising_Dataset_train_val/cable/Val/Degraded_image/combined/010.png to structured_data/Val/degraded/cable_combined_001.png
#   Processing defect type: cut_outer_insulation in category: Degraded_image
# Copied Denoising_Dataset_train_val/cable/Val/Degraded_image/cut_outer_insulation/008.png to structured_data/Val/degraded/cable_cut_outer_insulation_001.png
#   Processing defect type: bent_wire in category: Degraded_image
# Copied Denoising_Dataset_train_val/cable/Val/Degraded_image/bent_wire/012.png to structured_data/Val/degraded/cable_bent_wire_001.png
#   Processing defect type: missing_cable in category: Degraded_image
# Copied Denoising_Dataset_train_val/cable/Val/Degraded_image/missing_cable/006.png to structured_data/Val/degraded/cable_missing_cable_001.png
#   Processing defect type: poke_insulation in category: Degraded_image
# Copied Denoising_Dataset_train_val/cable/Val/Degraded_image/poke_insulation/008.png to structured_data/Val/degraded/cable_poke_insulation_001.png
#   Processing defect type: cut_inner_insulation in category: Degraded_image
# Copied Denoising_Dataset_train_val/cable/Val/Degraded_image/cut_inner_insulation/007.png to structured_data/Val/degraded/cable_cut_inner_insulation_001.png
#   Processing defect type: cable_swap in category: Degraded_image
# Copied Denoising_Dataset_train_val/cable/Val/Degraded_image/cable_swap/007.png to structured_data/Val/degraded/cable_cable_swap_001.png
#   Processing defect type: missing_wire in category: GT_clean_image
# Copied Denoising_Dataset_train_val/cable/Val/GT_clean_image/missing_wire/007.png to structured_data/Val/ground_truth/cable_missing_wire_001.png
#   Processing defect type: combined in category: GT_clean_image
# Copied Denoising_Dataset_train_val/cable/Val/GT_clean_image/combined/010.png to structured_data/Val/ground_truth/cable_combined_001.png
#   Processing defect type: cut_outer_insulation in category: GT_clean_image
# Copied Denoising_Dataset_train_val/cable/Val/GT_clean_image/cut_outer_insulation/008.png to structured_data/Val/ground_truth/cable_cut_outer_insulation_001.png
#   Processing defect type: bent_wire in category: GT_clean_image
# Copied Denoising_Dataset_train_val/cable/Val/GT_clean_image/bent_wire/012.png to structured_data/Val/ground_truth/cable_bent_wire_001.png
#   Processing defect type: missing_cable in category: GT_clean_image
# Copied Denoising_Dataset_train_val/cable/Val/GT_clean_image/missing_cable/006.png to structured_data/Val/ground_truth/cable_missing_cable_001.png
#   Processing defect type: poke_insulation in category: GT_clean_image
# Copied Denoising_Dataset_train_val/cable/Val/GT_clean_image/poke_insulation/008.png to structured_data/Val/ground_truth/cable_poke_insulation_001.png
#   Processing defect type: cut_inner_insulation in category: GT_clean_image
# Copied Denoising_Dataset_train_val/cable/Val/GT_clean_image/cut_inner_insulation/007.png to structured_data/Val/ground_truth/cable_cut_inner_insulation_001.png
#   Processing defect type: cable_swap in category: GT_clean_image
# Copied Denoising_Dataset_train_val/cable/Val/GT_clean_image/cable_swap/007.png to structured_data/Val/ground_truth/cable_cable_swap_001.png
# Processing Train folder for class: zipper
#   Processing defect type: broken_teeth in category: Defect_mask
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/003_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_001.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/004_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_002.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/005_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_003.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/006_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_004.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/007_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_005.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/008_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_006.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/009_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_007.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/010_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_008.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/011_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_009.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/012_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_010.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/013_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_011.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/014_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_012.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/015_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_013.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/016_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_014.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/broken_teeth/017_mask.png to structured_data/Train/defect_mask/zipper_broken_teeth_015.png
#   Processing defect type: fabric_border in category: Defect_mask
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/000_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_001.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/001_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_002.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/002_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_003.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/003_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_004.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/004_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_005.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/005_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_006.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/007_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_007.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/008_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_008.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/011_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_009.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/012_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_010.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/013_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_011.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/014_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_012.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_border/015_mask.png to structured_data/Train/defect_mask/zipper_fabric_border_013.png
#   Processing defect type: fabric_interior in category: Defect_mask
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_interior/000_mask.png to structured_data/Train/defect_mask/zipper_fabric_interior_001.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_interior/001_mask.png to structured_data/Train/defect_mask/zipper_fabric_interior_002.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_interior/002_mask.png to structured_data/Train/defect_mask/zipper_fabric_interior_003.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_interior/003_mask.png to structured_data/Train/defect_mask/zipper_fabric_interior_004.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_interior/004_mask.png to structured_data/Train/defect_mask/zipper_fabric_interior_005.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_interior/005_mask.png to structured_data/Train/defect_mask/zipper_fabric_interior_006.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_interior/007_mask.png to structured_data/Train/defect_mask/zipper_fabric_interior_007.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_interior/008_mask.png to structured_data/Train/defect_mask/zipper_fabric_interior_008.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_interior/012_mask.png to structured_data/Train/defect_mask/zipper_fabric_interior_009.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_interior/013_mask.png to structured_data/Train/defect_mask/zipper_fabric_interior_010.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_interior/014_mask.png to structured_data/Train/defect_mask/zipper_fabric_interior_011.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/fabric_interior/015_mask.png to structured_data/Train/defect_mask/zipper_fabric_interior_012.png
#   Processing defect type: combined in category: Defect_mask
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/combined/003_mask.png to structured_data/Train/defect_mask/zipper_combined_001.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/combined/004_mask.png to structured_data/Train/defect_mask/zipper_combined_002.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/combined/005_mask.png to structured_data/Train/defect_mask/zipper_combined_003.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/combined/006_mask.png to structured_data/Train/defect_mask/zipper_combined_004.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/combined/007_mask.png to structured_data/Train/defect_mask/zipper_combined_005.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/combined/008_mask.png to structured_data/Train/defect_mask/zipper_combined_006.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/combined/009_mask.png to structured_data/Train/defect_mask/zipper_combined_007.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/combined/010_mask.png to structured_data/Train/defect_mask/zipper_combined_008.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/combined/011_mask.png to structured_data/Train/defect_mask/zipper_combined_009.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/combined/012_mask.png to structured_data/Train/defect_mask/zipper_combined_010.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/combined/014_mask.png to structured_data/Train/defect_mask/zipper_combined_011.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/combined/015_mask.png to structured_data/Train/defect_mask/zipper_combined_012.png
#   Processing defect type: rough in category: Defect_mask
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/000_mask.png to structured_data/Train/defect_mask/zipper_rough_001.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/001_mask.png to structured_data/Train/defect_mask/zipper_rough_002.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/002_mask.png to structured_data/Train/defect_mask/zipper_rough_003.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/003_mask.png to structured_data/Train/defect_mask/zipper_rough_004.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/004_mask.png to structured_data/Train/defect_mask/zipper_rough_005.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/006_mask.png to structured_data/Train/defect_mask/zipper_rough_006.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/007_mask.png to structured_data/Train/defect_mask/zipper_rough_007.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/008_mask.png to structured_data/Train/defect_mask/zipper_rough_008.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/010_mask.png to structured_data/Train/defect_mask/zipper_rough_009.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/012_mask.png to structured_data/Train/defect_mask/zipper_rough_010.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/014_mask.png to structured_data/Train/defect_mask/zipper_rough_011.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/015_mask.png to structured_data/Train/defect_mask/zipper_rough_012.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/rough/016_mask.png to structured_data/Train/defect_mask/zipper_rough_013.png
#   Processing defect type: squeezed_teeth in category: Defect_mask
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/squeezed_teeth/000_mask.png to structured_data/Train/defect_mask/zipper_squeezed_teeth_001.png
# Copied Denoising_Dataset_train_val/zipper/Train/Defect_mask/squeezed_teeth/001_mask.png to structured_data/Train/defect_mask/zipper_squeezed_teeth_002.png
# ...
# Copied Denoising_Dataset_train_val/capsule/Train/Degraded_image/scratch/020.png to structured_data/Train/degraded/capsule_scratch_016.png
# Copied Denoising_Dataset_train_val/capsule/Train/Degraded_image/scratch/021.png to structured_data/Train/degraded/capsule_scratch_017.png
# Copied Denoising_Dataset_train_val/capsule/Train/Degraded_image/scratch/022.png to structured_data/Train/degraded/capsule_scratch_018.png
#   Processing defect type: crack in category: GT_clean_image
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/crack/000.png to structured_data/Train/ground_truth/capsule_crack_001.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/crack
category: GT_clean_image
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/000.png to structured_data/Train/ground_truth/capsule_faulty_imprint_001.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/001.png to structured_data/Train/ground_truth/capsule_faulty_imprint_002.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/002.png to structured_data/Train/ground_truth/capsule_faulty_imprint_003.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/003.png to structured_data/Train/ground_truth/capsule_faulty_imprint_004.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/004.png to structured_data/Train/ground_truth/capsule_faulty_imprint_005.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/005.png to structured_data/Train/ground_truth/capsule_faulty_imprint_006.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/006.png to structured_data/Train/ground_truth/capsule_faulty_imprint_007.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/007.png to structured_data/Train/ground_truth/capsule_faulty_imprint_008.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/008.png to structured_data/Train/ground_truth/capsule_faulty_imprint_009.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/009.png to structured_data/Train/ground_truth/capsule_faulty_imprint_010.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/010.png to structured_data/Train/ground_truth/capsule_faulty_imprint_011.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/011.png to structured_data/Train/ground_truth/capsule_faulty_imprint_012.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/013.png to structured_data/Train/ground_truth/capsule_faulty_imprint_013.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/015.png to structured_data/Train/ground_truth/capsule_faulty_imprint_014.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/016.png to structured_data/Train/ground_truth/capsule_faulty_imprint_015.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/018.png to structured_data/Train/ground_truth/capsule_faulty_imprint_016.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/faulty_imprint/020.png to structured_data/Train/ground_truth/capsule_faulty_imprint_017.png
#   Processing defect type: scratch in category: GT_clean_image
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/000.png to structured_data/Train/ground_truth/capsule_scratch_001.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/001.png to structured_data/Train/ground_truth/capsule_scratch_002.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/002.png to structured_data/Train/ground_truth/capsule_scratch_003.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/003.png to structured_data/Train/ground_truth/capsule_scratch_004.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/004.png to structured_data/Train/ground_truth/capsule_scratch_005.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/006.png to structured_data/Train/ground_truth/capsule_scratch_006.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/007.png to structured_data/Train/ground_truth/capsule_scratch_007.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/008.png to structured_data/Train/ground_truth/capsule_scratch_008.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/011.png to structured_data/Train/ground_truth/capsule_scratch_009.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/012.png to structured_data/Train/ground_truth/capsule_scratch_010.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/013.png to structured_data/Train/ground_truth/capsule_scratch_011.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/014.png to structured_data/Train/ground_truth/capsule_scratch_012.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/015.png to structured_data/Train/ground_truth/capsule_scratch_013.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/016.png to structured_data/Train/ground_truth/capsule_scratch_014.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/019.png to structured_data/Train/ground_truth/capsule_scratch_015.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/020.png to structured_data/Train/ground_truth/capsule_scratch_016.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/021.png to structured_data/Train/ground_truth/capsule_scratch_017.png
# Copied Denoising_Dataset_train_val/capsule/Train/GT_clean_image/scratch/022.png to structured_data/Train/ground_truth/capsule_scratch_018.png
# Processing Val folder for class: capsule
#   Processing defect type: crack in category: Defect_mask
# Copied Denoising_Dataset_train_val/capsule/Val/Defect_mask/crack/022_mask.png to structured_data/Val/defect_mask/capsule_crack_001.png
#   Processing defect type: poke in category: Defect_mask
# Copied Denoising_Dataset_train_val/capsule/Val/Defect_mask/poke/014_mask.png to structured_data/Val/defect_mask/capsule_poke_001.png
#   Processing defect type: squeeze in category: Defect_mask
# Copied Denoising_Dataset_train_val/capsule/Val/Defect_mask/squeeze/013_mask.png to structured_data/Val/defect_mask/capsule_squeeze_001.png
#   Processing defect type: faulty_imprint in category: Defect_mask
# Copied Denoising_Dataset_train_val/capsule/Val/Defect_mask/faulty_imprint/021_mask.png to structured_data/Val/defect_mask/capsule_faulty_imprint_001.png
#   Processing defect type: scratch in category: Defect_mask
# Copied Denoising_Dataset_train_val/capsule/Val/Defect_mask/scratch/017_mask.png to structured_data/Val/defect_mask/capsule_scratch_001.png
#   Processing defect type: crack in category: Degraded_image
# Copied Denoising_Dataset_train_val/capsule/Val/Degraded_image/crack/022.png to structured_data/Val/degraded/capsule_crack_001.png
#   Processing defect type: poke in category: Degraded_image
# Copied Denoising_Dataset_train_val/capsule/Val/Degraded_image/poke/014.png to structured_data/Val/degraded/capsule_poke_001.png
#   Processing defect type: squeeze in category: Degraded_image
# Copied Denoising_Dataset_train_val/capsule/Val/Degraded_image/squeeze/013.png to structured_data/Val/degraded/capsule_squeeze_001.png
#   Processing defect type: faulty_imprint in category: Degraded_image
# Copied Denoising_Dataset_train_val/capsule/Val/Degraded_image/faulty_imprint/021.png to structured_data/Val/degraded/capsule_faulty_imprint_001.png
#   Processing defect type: scratch in category: Degraded_image
# Copied Denoising_Dataset_train_val/capsule/Val/Degraded_image/scratch/017.png to structured_data/Val/degraded/capsule_scratch_001.png
#   Processing defect type: crack in category: GT_clean_image
# Copied Denoising_Dataset_train_val/capsule/Val/GT_clean_image/crack/022.png to structured_data/Val/ground_truth/capsule_crack_001.png
#   Processing defect type: poke in category: GT_clean_image
# Copied Denoising_Dataset_train_val/capsule/Val/GT_clean_image/poke/014.png to structured_data/Val/ground_truth/capsule_poke_001.png
#   Processing defect type: squeeze in category: GT_clean_image
# Copied Denoising_Dataset_train_val/capsule/Val/GT_clean_image/squeeze/013.png to structured_data/Val/ground_truth/capsule_squeeze_001.png
#   Processing defect type: faulty_imprint in category: GT_clean_image
# Copied Denoising_Dataset_train_val/capsule/Val/GT_clean_image/faulty_imprint/021.png to structured_data/Val/ground_truth/capsule_faulty_imprint_001.png
#   Processing defect type: scratch in category: GT_clean_image
# Copied Denoising_Dataset_train_val/capsule/Val/GT_clean_image/scratch/017.png to structured_data/Val/ground_truth/capsule_scratch_001.png

# %%
# %run /root/DWDP/Data/clean_dataset.py
# Out:
# Unmatched files to be deleted in 'train' category:
#
# Unmatched files to be deleted in 'val' category:
#
# Unmatched file deletion process completed successfully.

# %%
# %run /root/DWDP/Data/inspect_dataset.py
# Out:
# Counting shapes in folder: degraded (train)
#
# Counting shapes in folder: defect_mask (train)
#
# Counting shapes in folder: ground_truth (train)
#
# Image shape counts in 'train' category:
# Shape (H x W): 1000 x 1000 - 255 images
# Shape (H x W): 1024 x 1024 - 1746 images
# Shape (H x W): 700 x 700 - 159 images
# Shape (H x W): 800 x 800 - 309 images
# Shape (H x W): 840 x 840 - 192 images
# Shape (H x W): 900 x 900 - 135 images
#
# Counting shapes in folder: degraded (val)
#
# Counting shapes in folder: defect_mask (val)
#
# Counting shapes in folder: ground_truth (val)
#
# Image shape counts in 'val' category:
# Shape (H x W): 1024 x 1024 - 165 images
# Shape (H x W): 800 x 800 - 33 images
# Shape (H x W): 1000 x 1000 - 15 images
# Shape (H x W): 840 x 840 - 15 images
# Shape (H x W): 700 x 700 - 18 images
# Shape (H x W): 900 x 900 - 18 images
#
# Image shape counting completed.
